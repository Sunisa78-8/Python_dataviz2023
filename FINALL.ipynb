# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunisa78-8/Python_dataviz2023/blob/main/FINALL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.   นางสาวสุชาดา อุปพงษ์ 643020524-4
# 2. นางสาวสุชานาถ พิลาภ 643021276-2
# 3. นางสาวอนัญญา พูลสวัสดิ์ 643020526-0
# 4. นางสาววริศรา ปันลา 643020519-7
# 5. นายตะวัน เบ้าหล่อเพชร 643020501-6
# 6. นางสาวสุนิสา อุดมขันธุ์ 643021278-8

# %% [markdown]
# # เอาข้อมูลเข้า

# %%
from google.colab import drive # เชื่อมบัญชีกับ google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import os

# %%
#เข้าไป path ใน google drive
import os
os.chdir('/content/drive/MyDrive/Final_Dataviz/Final2023_DataViz')

# !pwd #เช็ค path ที่กำลังทำงานอยู่
# Out:
# /content/drive/.shortcut-targets-by-id/1hJRbv1gQq_buBvNPn3Uy86oBasUU04FN/Final2023_DataViz

# %%
# !ls
# Out:
# Final.pdf				 POS_transactions_20171207-20171219.csv
# POS_operator_logs_20171207-20171219.csv  POS_transactions_20190213-20190226.csv
# POS_operator_logs_20190213-20190226.csv  POS_transactions_20190328-20190410.csv
# POS_operator_logs_20190328-20190410.csv

# %%
op1= pd.read_csv('/content/drive/MyDrive/Final_Dataviz/Final2023_DataViz/POS_operator_logs_20171207-20171219.csv')
op2= pd.read_csv('/content/drive/MyDrive/Final_Dataviz/Final2023_DataViz/POS_operator_logs_20190213-20190226.csv')
op3= pd.read_csv('/content/drive/MyDrive/Final_Dataviz/Final2023_DataViz/POS_operator_logs_20190328-20190410.csv')
tr1= pd.read_csv('/content/drive/MyDrive/Final_Dataviz/Final2023_DataViz/POS_transactions_20171207-20171219.csv')
tr2= pd.read_csv('/content/drive/MyDrive/Final_Dataviz/Final2023_DataViz/POS_transactions_20190213-20190226.csv')
tr3= pd.read_csv('/content/drive/MyDrive/Final_Dataviz/Final2023_DataViz/POS_transactions_20190328-20190410.csv')

# %% [markdown]
# # เช็คค่า NULL

# %%
op1.isnull().any()
# Out:
# WorkstationGroupID    False
# WorkstationID         False
# TranID                False
# BeginDateTime         False
# OperatorID            False
# Items                 False
# dtype: bool

# %%
op2.isnull().any()
# Out:
# WorkstationGroupID    False
# WorkstationID         False
# TranID                False
# BeginDateTime         False
# OperatorID            False
# Items                 False
# dtype: bool

# %%
op3.isnull().any()
# Out:
# WorkstationGroupID    False
# WorkstationID         False
# TranID                False
# BeginDateTime         False
# OperatorID            False
# Items                 False
# dtype: bool

# %%
tr1.isnull().any()
# Out:
# WorkstationGroupID    False
# TranID                False
# BeginDateTime         False
# EndDateTime           False
# OperatorID            False
# TranTime              False
# BreakTime             False
# ArtNum                False
# TNcash                False
# TNcard                False
# Amount                False
# dtype: bool

# %%
tr2.isnull().any()
# Out:
# WorkstationGroupID    False
# TranID                False
# BeginDateTime         False
# EndDateTime           False
# OperatorID            False
# TranTime              False
# BreakTime             False
# ArtNum                False
# TNcash                False
# TNcard                False
# Amount                False
# dtype: bool

# %%
tr3.isnull().any()
# Out:
# WorkstationGroupID    False
# TranID                False
# BeginDateTime         False
# EndDateTime           False
# OperatorID            False
# TranTime              False
# BreakTime             False
# ArtNum                False
# TNcash                False
# TNcard                False
# Amount                False
# dtype: bool

# %% [markdown]
# #MERGE

# %%
table_merge1 = op1.merge(tr1, how ='left', left_on='OperatorID',right_on='OperatorID')
print(table_merge1.shape)
table_merge1.head()
# Out:
# (7329230, 16)
#    WorkstationGroupID_x  WorkstationID       TranID_x      BeginDateTime_x  \
# 0                     8             16  1712071060162  2017-12-07T06:04:01
# 1                     8             16  1712071060162  2017-12-07T06:04:01
# 2                     8             16  1712071060162  2017-12-07T06:04:01
# 3                     8             16  1712071060162  2017-12-07T06:04:01
# 4                     8             16  1712071060162  2017-12-07T06:04:01
#
#    OperatorID           Items  WorkstationGroupID_y      TranID_y  \
# 0         266  OperatorSignOn                   8.0  1.712071e+12
# 1         266  OperatorSignOn                   8.0  1.712071e+12
# 2         266  OperatorSignOn                   8.0  1.712071e+12
# 3         266  OperatorSignOn                   8.0  1.712071e+13
# 4         266  OperatorSignOn                   8.0  1.712071e+13
#
#        BeginDateTime_y          EndDateTime  TranTime  BreakTime  ArtNum  \
# ...

# %%
table_merge2 = op2.merge(tr2, how ='left', left_on='OperatorID',right_on='OperatorID')
print(table_merge2.shape)
table_merge2.head()
# Out:
# (8638578, 16)
#    WorkstationGroupID_x  WorkstationID       TranID_x      BeginDateTime_x  \
# 0                     8             19  1902131060192  2019-02-13T05:37:55
# 1                     8             19  1902131060192  2019-02-13T05:37:55
# 2                     8             19  1902131060192  2019-02-13T05:37:55
# 3                     8             19  1902131060192  2019-02-13T05:37:55
# 4                     8             19  1902131060192  2019-02-13T05:37:55
#
#    OperatorID           Items  WorkstationGroupID_y      TranID_y  \
# 0         269  OperatorSignOn                   8.0  1.902131e+12
# 1         269  OperatorSignOn                   8.0  1.902131e+12
# 2         269  OperatorSignOn                   8.0  1.902131e+12
# 3         269  OperatorSignOn                   8.0  1.902131e+12
# 4         269  OperatorSignOn                   8.0  1.902131e+13
#
#        BeginDateTime_y          EndDateTime  TranTime  BreakTime  ArtNum  \
# ...

# %%
table_merge3 = op3.merge(tr3, how ='left', left_on='OperatorID',right_on='OperatorID')
print(table_merge3.shape)
table_merge3.head()
# Out:
# (5905674, 16)
#    WorkstationGroupID_x  WorkstationID       TranID_x      BeginDateTime_x  \
# 0                     8             19  1903281060192  2019-03-28T06:08:13
# 1                     8             19  1903281060192  2019-03-28T06:08:13
# 2                     8             19  1903281060192  2019-03-28T06:08:13
# 3                     8             19  1903281060192  2019-03-28T06:08:13
# 4                     8             19  1903281060192  2019-03-28T06:08:13
#
#    OperatorID           Items  WorkstationGroupID_y      TranID_y  \
# 0         269  OperatorSignOn                     8  1.903281e+12
# 1         269  OperatorSignOn                     8  1.903281e+12
# 2         269  OperatorSignOn                     8  1.903281e+12
# 3         269  OperatorSignOn                     8  1.903281e+12
# 4         269  OperatorSignOn                     8  1.903281e+12
#
#        BeginDateTime_y          EndDateTime  TranTime  BreakTime  ArtNum  \
# ...

# %%
pd.concat([table_merge1, table_merge2, table_merge3] , axis=0)
# Out:
#          WorkstationGroupID_x  WorkstationID         TranID_x  \
# 0                           8             16    1712071060162
# 1                           8             16    1712071060162
# 2                           8             16    1712071060162
# 3                           8             16    1712071060162
# 4                           8             16    1712071060162
# ...                       ...            ...              ...
# 5905669                     1              4  190410106041061
# 5905670                     1              4  190410106041061
# 5905671                     1              4  190410106041061
# 5905672                     1              4  190410106041061
# 5905673                     1              4  190410106041061
#
#              BeginDateTime_x  OperatorID            Items  \
# 0        2017-12-07T06:04:01         266   OperatorSignOn
# 1        2017-12-07T06:04:01         266   OperatorSignOn
# ...

# %%
ploy = pd.concat([table_merge1, table_merge2, table_merge3] , axis=0)

# %%
ploy.head(5)
# Out:
#    WorkstationGroupID_x  WorkstationID       TranID_x      BeginDateTime_x  \
# 0                     8             16  1712071060162  2017-12-07T06:04:01
# 1                     8             16  1712071060162  2017-12-07T06:04:01
# 2                     8             16  1712071060162  2017-12-07T06:04:01
# 3                     8             16  1712071060162  2017-12-07T06:04:01
# 4                     8             16  1712071060162  2017-12-07T06:04:01
#
#    OperatorID           Items  WorkstationGroupID_y      TranID_y  \
# 0         266  OperatorSignOn                   8.0  1.712071e+12
# 1         266  OperatorSignOn                   8.0  1.712071e+12
# 2         266  OperatorSignOn                   8.0  1.712071e+12
# 3         266  OperatorSignOn                   8.0  1.712071e+13
# 4         266  OperatorSignOn                   8.0  1.712071e+13
#
#        BeginDateTime_y          EndDateTime  TranTime  BreakTime  ArtNum  \
# ...
