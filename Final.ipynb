# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunisa78-8/Python_dataviz2023/blob/main/Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive # เชื่อมบัญชีกับ google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import os

# %%
#เข้าไป path ใน google drive
import os
os.chdir('/content/drive/MyDrive/Final_Dataviz/Final2023_DataViz')

# !pwd #เช็ค path ที่กำลังทำงานอยู่
# Out:
# /content/drive/.shortcut-targets-by-id/1hJRbv1gQq_buBvNPn3Uy86oBasUU04FN/Final2023_DataViz

# %%
# !ls
# Out:
# Final.pdf				 POS_transactions_20171207-20171219.csv
# POS_operator_logs_20171207-20171219.csv  POS_transactions_20190213-20190226.csv
# POS_operator_logs_20190213-20190226.csv  POS_transactions_20190328-20190410.csv
# POS_operator_logs_20190328-20190410.csv

# %%
operator1 = pd.read_csv('/content/drive/MyDrive/Final_Dataviz/Final2023_DataViz/POS_operator_logs_20171207-20171219.csv')
operator2 = pd.read_csv('/content/drive/MyDrive/Final_Dataviz/Final2023_DataViz/POS_operator_logs_20190213-20190226.csv')
operator3  = pd.read_csv('/content/drive/MyDrive/Final_Dataviz/Final2023_DataViz/POS_operator_logs_20190328-20190410.csv')
tran1 = pd.read_csv('/content/drive/MyDrive/Final_Dataviz/Final2023_DataViz/POS_transactions_20171207-20171219.csv')
tran2 = pd.read_csv('/content/drive/MyDrive/Final_Dataviz/Final2023_DataViz/POS_transactions_20190213-20190226.csv')
tran3= pd.read_csv('/content/drive/MyDrive/Final_Dataviz/Final2023_DataViz/POS_transactions_20190328-20190410.csv')

# %%
operator1.isnull().any()
# Out:
# WorkstationGroupID    False
# WorkstationID         False
# TranID                False
# BeginDateTime         False
# OperatorID            False
# Items                 False
# dtype: bool

# %%
operator2.isnull().any()
# Out:
# WorkstationGroupID    False
# WorkstationID         False
# TranID                False
# BeginDateTime         False
# OperatorID            False
# Items                 False
# dtype: bool

# %%
operator3.isnull().any()
# Out:
# WorkstationGroupID    False
# WorkstationID         False
# TranID                False
# BeginDateTime         False
# OperatorID            False
# Items                 False
# dtype: bool

# %%
tran1.isnull().any()
# Out:
# WorkstationGroupID    False
# TranID                False
# BeginDateTime         False
# EndDateTime           False
# OperatorID            False
# TranTime              False
# BreakTime             False
# ArtNum                False
# TNcash                False
# TNcard                False
# Amount                False
# dtype: bool

# %%
tran2.isnull().any()
# Out:
# WorkstationGroupID    False
# TranID                False
# BeginDateTime         False
# EndDateTime           False
# OperatorID            False
# TranTime              False
# BreakTime             False
# ArtNum                False
# TNcash                False
# TNcard                False
# Amount                False
# dtype: bool

# %%
tran3.isnull().any()
# Out:
# WorkstationGroupID    False
# TranID                False
# BeginDateTime         False
# EndDateTime           False
# OperatorID            False
# TranTime              False
# BreakTime             False
# ArtNum                False
# TNcash                False
# TNcard                False
# Amount                False
# dtype: bool

# %%
operator = pd.concat([operator1,operator2,operator3],ignore_index=True)

# %%
transactions = pd.concat([tran1,tran2,tran3],ignore_index = True)

# %%
operator
# Out:
#        WorkstationGroupID  WorkstationID           TranID  \
# 0                       8             16    1712071060162
# 1                       8             15    1712071060152
# 2                       8             14    1712071060142
# 3                       8             18    1712071060182
# 4                       8             17    1712071060172
# ...                   ...            ...              ...
# 14099                   1              3   19041010603798
# 14100                   1              4  190410106041042
# 14101                   1              4  190410106041044
# 14102                   1              5   19041010605515
# 14103                   1              4  190410106041061
#
#              BeginDateTime  OperatorID            Items
# 0      2017-12-07T06:04:01         266   OperatorSignOn
# 1      2017-12-07T06:04:15         265   OperatorSignOn
# 2      2017-12-07T06:05:36         264   OperatorSignOn
# ...

# %%
transactions
# Out:
#         WorkstationGroupID        TranID        BeginDateTime  \
# 0                        1  1.712071e+14  2017-12-07T14:23:23
# 1                        1  1.712071e+14  2017-12-07T14:25:09
# 2                        1  1.712071e+14  2017-12-07T14:27:28
# 3                        1  1.712071e+14  2017-12-07T14:28:04
# 4                        1  1.712071e+14  2017-12-07T14:29:40
# ...                    ...           ...                  ...
# 163264                   1  1.904101e+14  2019-04-10T14:05:20
# 163265                   1  1.904101e+14  2019-04-10T14:06:39
# 163266                   1  1.904101e+14  2019-04-10T14:07:51
# 163267                   1  1.904101e+14  2019-04-10T14:09:46
# 163268                   1  1.904101e+14  2019-04-10T14:10:29
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0       2017-12-07T14:24:36         101        73         33      23    True
# ...

# %%
pp = transactions.merge(operator,how='left' , left_on='WorkstationGroupID' , right_on = 'WorkstationGroupID')

# %%
pp =pd.merge(transactions,operator,how = 'left' , on=['WorkstationGroupID'])
