# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunisa78-8/Python_dataviz2023/blob/main/DataViz02_Data_Distribution_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Data

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# # Scatter Plot
#   ดูการกระจายของข้อมูล  // เอาข้อมูลมาพอตเป็นจุด โดยตำแหน่งแต่ละค่า ค่าในคอลัมน์
#   ![image.png](data:image/png;base64,...)

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter([1,-1],[2,-1]) # ( x,y)  ([จุดแรกในแกน x = 1, จุดสอง ค่าในแกน x = -1],[จุดแรกค่าในแกน y=2,จุดสองค่าในแกน y= -1 ])

# %%
plt.scatter([1,-1,0],[2,-1,0.5])

# %%
plt.scatter(df['PetalLength'],df['SepalLength']) #ความยาวกลีบดอก เทียบกับ ความยาวกลีบเลี้ยง

# %% [markdown]
# ## เปลี่ยนสี
# c = arr -like or list of col / col เลยก็ได้  // list กำหนดสีเเต่ละประเภทได้

# %%
plt.scatter(df['PetalLength'],df['SepalLength'],c='b') # c คือระบุสิ

# %%
plt.scatter([1,-1,0],[2,-1,0.5]) ,c=['r','g','b']
# Out:
#   File "<ipython-input-13-d016b8a3874d>", line 1
#     plt.scatter([1,-1,0],[2,-1,0.5]) ,c=['r','g','b']
#                                       ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %% [markdown]
# ## ระบุสีให้แต่ละจุด

# %%
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
set(df['Name'])
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %% [markdown]
# ### แทนค่าชื่อดอกไม้ด้วยตัวอักษรแทนสี (r g b c m y k w)

# %%
df2 = df.replace({'Iris-setosa':'r', 'Iris-versicolor':'g', 'Iris-virginica':'b'})

# %%
df2.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth Name
# 0          5.1         3.5          1.4         0.2    r
# 1          4.9         3.0          1.4         0.2    r
# 2          4.7         3.2          1.3         0.2    r
# 3          4.6         3.1          1.5         0.2    r
# 4          5.0         3.6          1.4         0.2    r

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name']) # ความยาวกลีบเลี้ยง กลีบดอก #จำนวนสมาชิก ของ x y c ต้องเท่ากัน len()

# %% [markdown]
# Iris-setosa':'r', 'Iris-versicolor':'g', 'Iris-virginica':'b'
# r = ความยาวกลีบเลี้ยงน้อยกว่า g b //แต่ว่า มีความกว้างของกลีบเลี้ยงมากกว่า g b

# %%
plt.scatter(df2['SepalLength'],df2['SepalWidth'],c=df2['Name']) #ความยาว กลีบเลี้ยง กับความกว้าง กลีบเลี้ยง

# %% [markdown]
# ## เพิ่มรายละเอียดกราฟ  เวลาทำ ใส่รายละเอีนดให้ครบ

# %% [markdown]
# ### ชื่อแกน

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name'])
plt.xlabel('PetalLength') #ชื่อเเกน x
plt.ylabel('SepalLength') # ชื่อแกน y
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# ### ชื่อ marker

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga')

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga')
plt.legend()  #โชว์ // ให้วางตรงไหนของกราฟ
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# ### ชื่อกราฟ  สำคัญ

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('Comparing petal&sepal length of different iris flowers'); #ชื่อกราฟ

# %% [markdown]
# ## ใช้ ขนาดของ marker ในการแสดงค่าใน column
# s =  size เอาความกว้างของกลีบดอกมาเป็น size
# ![image.png](data:image/png;base64,...)

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=df2['PetalWidth'][:50])
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga',s=df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ขยายของขนาด marker ที่เล็กเกินไป

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50])
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# .0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ....................................................................................................................................................................................## ปรับความโปรงใสของ marker เพื่อให้มองเห็นจุดที่ถูกบัง (Bubble Chart)
# alpha

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50])
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers \n (sizes of the circle determine petal widths of the flowers)');

#ค่าแอลฟ่า ปรับจาง

# %% [markdown]
# ## เปลี่ยน หน้าตาของ Marker เพื่อความสวยงาม
# marker =  $c$ $ พอตตัวนส$

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50],marker='X')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100],marker='X')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:],marker='X')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50],marker='$s$')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100],marker='$c$')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:],marker='$g$')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ## แสดงแบบ 3 มิติ

# %%
ax = plt.axes(projection = "3d")
ax.scatter(df2['PetalLength'],df2['SepalLength'],df2['SepalWidth'],c=df2['Name'],s=80*df2['PetalWidth']) # x,y,z

# %%
ax = plt.axes(projection = "3d")
ax.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],df2['SepalWidth'][:50],c=df2['Name'][:50],s=80*df2['PetalWidth'][:50],label='setosa')
ax.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],df2['SepalWidth'][50:100],c=df2['Name'][50:100],s=80*df2['PetalWidth'][50:100],label='versicolor')
ax.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],df2['SepalWidth'][100:],c=df2['Name'][100:],s=80*df2['PetalWidth'][100:],label='verginica')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ### จบ 26 sep 2022

# %% [markdown]
# # Boxplot
# ![image.png](data:image/png;base64,...)
# ประกอบด้วย 4 ส่วนใหญ่ๆ
# 1.เริ่มจากเอาข้อมูลมาเรียง เเล้วได้ q1 2 3
# 2.fliers =outlier

# %% [markdown]
# ![1*2c21SkzJMf3frPXPAR_gZA-2.png](data:image/png;base64,...)

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(df['SepalLength']); #วาดการกระจายของความยาวกลีบเลี้ยง  // ; ปิด output ที่เป็นtext

# %%
plt.boxplot(df['SepalLength'],vert=False) # defult = Ture
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f2a17362510>,
#   <matplotlib.lines.Line2D at 0x7f2a173ca490>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f2a173cadd0>,
#   <matplotlib.lines.Line2D at 0x7f2a173caad0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f2a17362390>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2a173c3f90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2a173c3590>],
#  'means': []}

# %%
ybp = plt.boxplot(df['SepalLength'],vert=False)

# %%
ybp # return เป็น dict {}
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f2a17589390>,
#   <matplotlib.lines.Line2D at 0x7f2a17594fd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f2a17594a90>,
#   <matplotlib.lines.Line2D at 0x7f2a175946d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f2a17589cd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2a1758a950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2a1758ac90>],
#  'means': []}

# %% [markdown]
# median

# %%
ybp['medians'] # list สมาชิก 1ตัว

# %%
ybp['medians'][0] #อยากได้สมาชิกตัวที่ 0

# %%
ybp['medians'][0].get_xdata() #  xdata() ค่าในแนวแกน x
# Out:
# array([5.8, 5.8])

# %%
ybp['medians'][0].get_xdata() [0]
# Out:
# 5.8

# %%
ybp['medians'][0].get_ydata()  # ได้ค่าที่ไม่มีความหมาย
# Out:
# array([0.925, 1.075])

# %% [markdown]
# min

# %%
ybp['whiskers'] # สมาชิก 2 ตะว
# Out:
# [<matplotlib.lines.Line2D at 0x7f2a17589390>,
#  <matplotlib.lines.Line2D at 0x7f2a17594fd0>]

# %%
ybp['whiskers'][0].get_xdata()
# Out:
# array([5.1, 4.3])

# %%
min(ybp['whiskers'][0].get_xdata()) #min หลังจาก ลบout liner
# Out:
# 4.3

# %% [markdown]
# max

# %%
ybp['whiskers'][1].get_xdata()
# Out:
# array([6.4, 7.9])

# %%
max(ybp['whiskers'][1].get_xdata())
# Out:
# 7.9

# %%
ybp['caps'][1].get_xdata() # เส้น ยาวๆ
# Out:
# array([7.9, 7.9])

# %% [markdown]
# q1

# %%
ybp['boxes']

# %%
ybp['boxes'][0].get_xdata()
# Out:
# array([5.1, 5.1, 6.4, 6.4, 5.1])

# %%
ybp['boxes'][0].get_xdata()[0]
# Out:
# 5.1

# %%
max(ybp['whiskers'][0].get_xdata())
# Out:
# 5.1

# %% [markdown]
# outlier

# %%
ybp['fliers']

# %%
ybp['fliers'][0].get_xdata() #ไม่มี outlier
# Out:
# array([], dtype=float64)

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f2a1618cf50>,
#   <matplotlib.lines.Line2D at 0x7f2a162084d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f2a16208a10>,
#   <matplotlib.lines.Line2D at 0x7f2a16208f50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f2a1618c8d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2a16210510>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2a16210f90>],
#  'means': [<matplotlib.lines.Line2D at 0x7f2a16210a50>]}

# %%
plt.boxplot(df['SepalLength'],vert=False,meanline=True,showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f2a1605cf50>,
#   <matplotlib.lines.Line2D at 0x7f2a160604d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f2a16060a10>,
#   <matplotlib.lines.Line2D at 0x7f2a16060f50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f2a1605c990>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2a16068510>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2a16068f90>],
#  'means': [<matplotlib.lines.Line2D at 0x7f2a16068a50>]}

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans=True,meanprops={'marker':'o'})
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f2a16057550>,
#   <matplotlib.lines.Line2D at 0x7f2a16057a90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f2a16057fd0>,
#   <matplotlib.lines.Line2D at 0x7f2a15fdf550>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f2a1604ff50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2a15fdfad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2a15fe8590>],
#  'means': [<matplotlib.lines.Line2D at 0x7f2a15fe8050>]}

# %% [markdown]
# #  ตัวอย่าง Quiz กลุ่มfinal
#
# 1. เขียน function ที่รับ input เป็น output ของ boxplot แล้ว แสดงค่า min, max, q1, q2, q3
# 2. วาด boxplot เปรียบเทียบ การกระจายตัวของข้อมูล PetalLength ของดอก iris ทั้ง 3 ชนิด

# %%
bb = plt.boxplot(df['SepalLength'])

# %%
def detail_boxreturn(boxreturn):
    q1 = boxreturn['boxes'][0].get_ydata()[0]
    q2 = boxreturn['medians'][0].get_ydata()[0]
    q3 = boxreturn['boxes'][0].get_ydata()[2]
    minv = min(boxreturn['whiskers'][0].get_ydata())
    maxv = max(boxreturn['whiskers'][1].get_ydata())
    print(f'min = {minv}, max = {maxv}, q1 = {q1}, q2 = {q2}, q3 = {q3}')

# %%
detail_boxreturn(bb)
# Out:
# min = 4.3, max = 7.9, q1 = 5.1, q2 = 5.8, q3 = 6.4

# %%
bb2 = plt.boxplot(df['SepalLength'],vert=False)

# %%
detail_boxreturn(bb2)
# Out:
# min = 1.0, max = 1.0, q1 = 0.925, q2 = 0.925, q3 = 1.075

# %%
def detail_boxreturn_v2(boxreturn, vert=True):
    if vert == True:
        q1 = boxreturn['boxes'][0].get_ydata()[0]
        q2 = boxreturn['medians'][0].get_ydata()[0]
        q3 = boxreturn['boxes'][0].get_ydata()[2]
        minv = min(boxreturn['whiskers'][0].get_ydata())
        maxv = max(boxreturn['whiskers'][1].get_ydata())
    else: #vert == False
        q1 = boxreturn['boxes'][0].get_xdata()[0]
        q2 = boxreturn['medians'][0].get_xdata()[0]
        q3 = boxreturn['boxes'][0].get_xdata()[2]
        minv = min(boxreturn['whiskers'][0].get_xdata())
        maxv = max(boxreturn['whiskers'][1].get_xdata())

    print(f'min = {minv}, max = {maxv}, q1 = {q1}, q2 = {q2}, q3 = {q3}')

# %%
detail_boxreturn_v2(bb)
# Out:
# min = 4.3, max = 7.9, q1 = 5.1, q2 = 5.8, q3 = 6.4

# %%
detail_boxreturn_v2(bb2,vert=False)
# Out:
# min = 4.3, max = 7.9, q1 = 5.1, q2 = 5.8, q3 = 6.4

# %%
#วาด boxplot เปรียบเทียบ การกระจายตัวของข้อมูล PetalLength ของดอก iris ทั้ง 3 ชนิด
plt.boxplot(df['PetalLength'][:50],positions = [1] )
plt.boxplot(df['PetalLength'][50:100],positions = [2] )
plt.boxplot(df['PetalLength'][100:150],positions = [3] );

# %% [markdown]
# # Violin plot

# %%
bb = plt.boxplot(df['PetalLength'][:50])

# %%
plt.violinplot(df['PetalLength'][:50]) #เห็นการกระจายของ data
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7f2a15dbca90>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7f2a15dbc910>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7f2a15dbcc10>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7f2a15dbcb50>}

# %%
plt.subplot(1,2,1)
bb = plt.boxplot(df['PetalLength'][:50])
q1 = bb['boxes'][0].get_ydata()[0]
q2 = bb['medians'][0].get_ydata()[0]
q3 = bb['boxes'][0].get_ydata()[2]
plt.subplot(1,2,2)
vi = plt.violinplot(df['PetalLength'][:50],showmedians=True)

# %% [markdown]
# # quiz 6  ให้เปรียบเทียบการกระจายตัวของราคาบ้านเดี่ยวและคอนโด ระหว่างจังหวัด กทม ขอนแก่น และเชียงใหม่ (ด้วย  boxplot)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
unit = pd.read_csv('/content/drive/MyDrive/BPDV65/opendata_unittype.csv')
unit.head()
# Out:
#    row_number     unittype_id    project_id             name_th  \
# 0       27501   unittype_9565  project_2446           2 Bedroom
# 1       28777  unittype_10267  project_3543  บ้านแฝดสองชั้น Z-2
# 2       28865    unittype_471   project_143    1 Bedroom Type B
# 3       24988  unittype_19506  project_7766    Studio Floor 1-2
# 4       38596  unittype_10290  project_3551                TH 3
#
#    propertytype_id propertytype_name_en propertytype_name_th  \
# 0                2                Condo                คอนโด
# 1            20000           Twin house              บ้านแฝด
# 2                2                Condo                คอนโด
# 3                2                Condo                คอนโด
# 4                3             Townhome             ทาวน์โฮม
#
#    area_total_min_wa  area_usable_min  price_min  ...  count_room_guest  \
# 0                NaN             37.3  2500000.0  ...               1.0
# 1               40.0            150.0  2390000.0  ...               NaN
# 2                NaN             28.0        NaN  ...               NaN
# 3                NaN             27.0   170000.0  ...               NaN
# 4                NaN            182.0  2390000.0  ...               1.0
#
#    count_room_kitchen  count_room_living  count_room_maid  count_room_storage  \
# 0                 1.0                NaN              NaN                 NaN
# 1                 NaN                NaN              NaN                 NaN
# 2                 NaN                NaN              NaN                 NaN
# 3                 NaN                NaN              NaN                 NaN
# 4                 1.0                NaN              NaN                 2.0
#
#    count_room_utility         date_created         date_updated  source  \
# 0                 NaN  2021-11-19 18:00:09  2021-11-19 17:44:45  baania
# 1                 NaN  2022-01-27 14:30:04  2022-01-27 14:22:55  baania
# 2                 NaN  2022-01-14 15:00:10  2022-01-14 14:40:04  baania
# 3                 NaN  2020-12-04 10:40:59  2020-10-14 01:06:48  baania
# 4                 NaN  2021-11-12 13:30:08  2021-02-03 12:12:54  baania
#
#                                         url_unittype
# 0  https://baania.com/th/project/เฟ-ลิค-คอนโด-ลาด...
# 1  https://baania.com/th/project/เซน-บาย-ศิวาลัย-...
# 2  https://baania.com/th/project/วันพลัส-นายน์ทีน...
# 3  https://baania.com/th/project/บ้านสวนชมน้ำ-776...
# 4  https://baania.com/th/project/เบล็สทาวน์-ศรีนค...
#
# [5 rows x 27 columns]

# %%
project = pd.read_csv('/content/drive/MyDrive/BPDV65/opendata_project.csv')
project.head()
# Out:
#    row_number                project_id                             name_en  \
# 0      7880.0  5ee08d64dda791001299b2a6  Winning Residence Sukhumvit Praksa
# 1     16689.0             project_11326                    Gift Condominium
# 2       290.0  62739c4089233e001362b001    Sanrak 9 Sukprayoon Nong Krathum
# 3     20719.0              project_2010                     Baan Sansabai 1
# 4       199.0             project_16838          Baanpruksa Ratchapruek-345
#
#                               name_th propertytype_id propertytype_name_en  \
# 0  วินนิ่ง เรสซิเดนท์ สุขุมวิท แพรกษา               1       Detached House
# 1                 กิ๊ฟท์ คอนโดมิเนียม               2                Condo
# 2      แสนรัก 9 ศุขประยูร หนองกระทุ่ม               3             Townhome
# 3                       บ้านแสนสบาย 1               1       Detached House
# 4              บ้านพฤกษา ราชพฤกษ์-345               3             Townhome
#
#   propertytype_name_th  price_min     developer_id  \
# 0                 บ้าน  3790000.0  developer_10678
# 1                คอนโด  1100000.0   developer_7319
# 2             ทาวน์โฮม        0.0  developer_10510
# 3                 บ้าน        0.0  developer_10510
# 4             ทาวน์โฮม  1930000.0   developer_1026
#
#               developer_name_en  ... facility_meeting  facility_park  \
# 0  Winning Asset Plus Co., Ltd.  ...              NaN            NaN
# 1      Gift Asset Land Co.,Ltd.  ...              NaN            1.0
# 2                           NaN  ...              NaN            NaN
# 3                           NaN  ...              NaN            NaN
# 4  Preuksa Real Estate Co.,Ltd.  ...              NaN            1.0
#
#    facility_playground facility_pool facility_security         date_created  \
# 0                  NaN           1.0               1.0  2020-06-10 14:36:04
# 1                  NaN           1.0               1.0  2017-10-30 15:38:48
# 2                  NaN           NaN               NaN  2022-05-05 16:43:28
# 3                  NaN           NaN               NaN  2016-09-05 15:32:15
# 4                  NaN           1.0               1.0  2019-09-05 11:49:37
#
#            date_finish         date_updated  source  \
# 0                  NaN  2020-12-04 10:32:58  baania
# 1  2013-01-01 07:00:00  2020-12-04 10:49:00  baania
# 2                  NaN  2022-05-05 17:30:03  baania
# 3  1970-01-02 07:00:00  2020-12-04 10:45:31  baania
# 4  1970-01-02 07:00:00  2021-03-17 12:00:04  baania
#
#                                          url_project
# 0  https://baania.com/th/project/วินนิ่ง-เรสซิเดน...
# 1  https://baania.com/th/project/กิ๊ฟท์-คอนโดมิเน...
# 2  https://baania.com/th/project/แสนรัก-9-ศุขประย...
# 3  https://baania.com/th/project/บ้านแสนสบาย-1-pr...
# 4  https://baania.com/th/project/บ้านพฤกษา-ราชพฤก...
#
# [5 rows x 45 columns]

# %%
project_nodup = project.drop_duplicates(subset=['project_id'])
unit['province_name_th'] = unit['project_id'].map(project_nodup.set_index('project_id')['province_name_th']) #เอา province_name_en ของตาราง โปรเจค มาใส่ในตาราง unit
unit.dropna(subset=['propertytype_name_en','province_name_th'],inplace = True) # 2 columnนี้จะไม่มี missingแน่นอน แนวแถว
unit.fillna(value={'price_min':unit['price_min'].mean()},inplace = True) # แทนค่า missing ของ  price_min & area_usable_min ด้วย ค่าเฉลี่ย
U = unit[['propertytype_name_en','price_min','province_name_th']]
U
# Out:
#       propertytype_name_en     price_min province_name_th
# 0                    Condo  2.500000e+06    กรุงเทพมหานคร
# 1               Twin house  2.390000e+06        เชียงใหม่
# 2                    Condo  5.573595e+06        เชียงใหม่
# 3                    Condo  1.700000e+05          นนทบุรี
# 4                 Townhome  2.390000e+06      สมุทรปราการ
# ...                    ...           ...              ...
# 42620       Detached House  5.573595e+06    กรุงเทพมหานคร
# 42621       Detached House  7.490000e+06          นนทบุรี
# 42622             Townhome  5.573595e+06    กรุงเทพมหานคร
# 42623       Detached House  3.200000e+06    กรุงเทพมหานคร
# 42624       Detached House  3.790000e+06         ปทุมธานี
#
# [42449 rows x 3 columns]

# %%
HK = U[(U['propertytype_name_en']=='Detached House') & (U['province_name_th']=='ขอนแก่น')] #เฉพาะ Detached House
HK
# Out:
#       propertytype_name_en     price_min province_name_th
# 8           Detached House  9.900000e+05          ขอนแก่น
# 16          Detached House  2.200000e+06          ขอนแก่น
# 116         Detached House  4.423000e+06          ขอนแก่น
# 142         Detached House  5.573595e+06          ขอนแก่น
# 156         Detached House  2.250000e+06          ขอนแก่น
# ...                    ...           ...              ...
# 42267       Detached House  2.100000e+06          ขอนแก่น
# 42380       Detached House  3.070000e+06          ขอนแก่น
# 42441       Detached House  2.990000e+06          ขอนแก่น
# 42518       Detached House  2.690000e+06          ขอนแก่น
# 42596       Detached House  2.690000e+06          ขอนแก่น
#
# [697 rows x 3 columns]

# %%
CK = U[(U['propertytype_name_en']=='Condo') & (U['province_name_th']=='ขอนแก่น')] #เฉพาะ Detached House
CK
# Out:
#       propertytype_name_en     price_min province_name_th
# 105                  Condo  2.240000e+06          ขอนแก่น
# 151                  Condo  1.450000e+06          ขอนแก่น
# 535                  Condo  1.890000e+06          ขอนแก่น
# 591                  Condo  1.300000e+06          ขอนแก่น
# 1276                 Condo  5.573595e+06          ขอนแก่น
# ...                    ...           ...              ...
# 41232                Condo  2.100000e+06          ขอนแก่น
# 41335                Condo  5.573595e+06          ขอนแก่น
# 41701                Condo  5.573595e+06          ขอนแก่น
# 42064                Condo  5.573595e+06          ขอนแก่น
# 42207                Condo  2.650000e+06          ขอนแก่น
#
# [154 rows x 3 columns]

# %%
HB = U[(U['propertytype_name_en']=='Detached House') & (U['province_name_th']=='กรุงเทพมหานคร')] #เฉพาะ Detached House
HB
# Out:
#       propertytype_name_en     price_min province_name_th
# 5           Detached House  1.170000e+07    กรุงเทพมหานคร
# 11          Detached House  3.690000e+07    กรุงเทพมหานคร
# 49          Detached House  5.573595e+06    กรุงเทพมหานคร
# 88          Detached House  5.573595e+06    กรุงเทพมหานคร
# 132         Detached House  4.000000e+06    กรุงเทพมหานคร
# ...                    ...           ...              ...
# 42576       Detached House  2.890000e+07    กรุงเทพมหานคร
# 42599       Detached House  5.573595e+06    กรุงเทพมหานคร
# 42609       Detached House  5.573595e+06    กรุงเทพมหานคร
# 42620       Detached House  5.573595e+06    กรุงเทพมหานคร
# 42623       Detached House  3.200000e+06    กรุงเทพมหานคร
#
# [3420 rows x 3 columns]

# %%
CB = U[(U['propertytype_name_en']=='Condo') & (U['province_name_th']=='กรุงเทพมหานคร')] #เฉพาะ Detached House
CB
# Out:
#       propertytype_name_en     price_min province_name_th
# 0                    Condo  2.500000e+06    กรุงเทพมหานคร
# 17                   Condo  4.008000e+06    กรุงเทพมหานคร
# 22                   Condo  2.500000e+06    กรุงเทพมหานคร
# 26                   Condo  3.500000e+06    กรุงเทพมหานคร
# 27                   Condo  1.750000e+06    กรุงเทพมหานคร
# ...                    ...           ...              ...
# 42570                Condo  7.350000e+06    กรุงเทพมหานคร
# 42578                Condo  5.573595e+06    กรุงเทพมหานคร
# 42585                Condo  3.750000e+06    กรุงเทพมหานคร
# 42604                Condo  3.120000e+06    กรุงเทพมหานคร
# 42607                Condo  1.700000e+07    กรุงเทพมหานคร
#
# [6204 rows x 3 columns]

# %%
HC = U[(U['propertytype_name_en']=='Detached House') & (U['province_name_th']=='เชียงใหม่')] #เฉพาะ Detached House
HC
# Out:
#       propertytype_name_en     price_min province_name_th
# 19          Detached House  5.573595e+06        เชียงใหม่
# 21          Detached House  7.500000e+06        เชียงใหม่
# 35          Detached House  1.100000e+07        เชียงใหม่
# 51          Detached House  2.590000e+06        เชียงใหม่
# 52          Detached House  1.645625e+06        เชียงใหม่
# ...                    ...           ...              ...
# 42434       Detached House  3.830000e+06        เชียงใหม่
# 42470       Detached House  3.390000e+06        เชียงใหม่
# 42501       Detached House  3.590000e+06        เชียงใหม่
# 42516       Detached House  1.590000e+06        เชียงใหม่
# 42526       Detached House  6.500000e+05        เชียงใหม่
#
# [2272 rows x 3 columns]

# %%
CC = U[(U['propertytype_name_en']=='Condo') & (U['province_name_th']=='เชียงใหม่')] #เฉพาะ Detached House
CC
# Out:
#       propertytype_name_en     price_min province_name_th
# 2                    Condo  5.573595e+06        เชียงใหม่
# 29                   Condo  5.573595e+06        เชียงใหม่
# 33                   Condo  5.573595e+06        เชียงใหม่
# 326                  Condo  1.590000e+06        เชียงใหม่
# 329                  Condo  1.530000e+06        เชียงใหม่
# ...                    ...           ...              ...
# 42513                Condo  5.573595e+06        เชียงใหม่
# 42537                Condo  5.573595e+06        เชียงใหม่
# 42568                Condo  5.500000e+06        เชียงใหม่
# 42577                Condo  5.573595e+06        เชียงใหม่
# 42602                Condo  6.345000e+06        เชียงใหม่
#
# [877 rows x 3 columns]

# %% [markdown]
# Boxplot

# %%
from matplotlib import pyplot as plt #เพื่อ plot graph
import matplotlib #เพื่อปรับแต่งขนาดของกราฟ
matplotlib.rcParams['figure.figsize']=[20,20] # กำหนดขนาดกราฟ

# %%
plt.subplot(2,3,1)
plt.boxplot(HK['price_min']);
plt.title('HOME AT KHON KEAN')

plt.subplot(2,3,2)
plt.boxplot(HB['price_min']);
plt.title('HOME AT BANGKOK')

plt.subplot(2,3,3)
plt.boxplot(HC['price_min']);
plt.title('HOME AT CHAING MAI')

plt.subplot(2,3,4)
plt.boxplot(CK['price_min']);
plt.title('CONDO AT KHON KEAN')

plt.subplot(2,3,5)
plt.boxplot(CB['price_min']);
plt.title('CONDO AT BANGKOK')

plt.subplot(2,3,6)
plt.boxplot(CC['price_min']);
plt.title('CONDO AT CHAING MAI')
# Out:
# Text(0.5, 1.0, 'CONDO AT CHAING MAI')
